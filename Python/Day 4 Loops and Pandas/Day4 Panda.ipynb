# %% [markdown]
# CSV file and XLSX file

# %%
import pandas as pd

xlsx_path = 'movies_top_awards.xlsx'
df = pd.read_excel(xlsx_path)
# csv_path = 'movies_top_awards.csv'
# df = pd.read_csv(csv_path)
df.head()
# Out:
#                                            Movie  Release  Oscar number  \
# 0                                        Ben-Hur     1959             5
# 1  The Lord of the Rings: The Return of the King     2003            11
# 2                                        Titanic     1997            11
# 3                                West Side Story     1961            10
# 4                            The English Patient     1996             9
#
#    Nominations                     Director  Duration (minutes)  \
# 0           12                William Wyler                 212
# 1           11                Peter Jackson                 201
# 2           14                James Cameron                 195
# 3           11  Robert Wise, Jerome Robbins                 152
# 4           12            Anthony Minghella                  16
#
#                            Language
# 0                           English
# 1                           English
# ...

# %% [markdown]
# 1.Assign the DataFrame

# %%
# Oscar number and Nominations columns to the variable 'new'
new = df[['Oscar number', 'Nominations']]

# Language to the variable 'newer'
newer = df.drop(columns=['Language'])

new, newer
# Out:
# (    Oscar number  Nominations
#  0              5           12
#  1             11           11
#  2             11           14
#  3             10           11
#  4              9           12
#  5              9            9
#  6              9            9
#  7              8           11
#  8              8           10
#  9              8           13
#  10             8           11
#  11             8           13
#  12             8           12
#  13             8           12,
#                                              Movie  Release  Oscar number  \
#  0                                         Ben-Hur     1959             5
#  1   The Lord of the Rings: The Return of the King     2003            11
#  2                                         Titanic     1997            11
#  3                                 West Side Story     1961            10
#  4                             The English Patient     1996             9
# ...

# %% [markdown]
# 2. Retrieve the rows of all the movies

# %%
# Duration longer than 200 minutes
long_duration_movies = df[df['Duration (minutes)'] > 200]

# Less than 12 Oscar nominations
less_than_12_nominations = df[df['Nominations'] < 12]

long_duration_movies, less_than_12_nominations
df
# Out:
#     Unnamed: 0                                              Movie  Release  \
# 0            0      The Lord of the Rings: The Return of the King     2003
# 1            1                                            Titanic     1997
# 2            2                                    West Side Story     1961
# 3            3                                The English Patient     1996
# 4            4                           The Silence of the Lambs     1991
# 5            5                                   The Last Emperor     1987
# 6            6                                            Amadeus     1984
# 7            7                                            Cabaret     1972
# 8            8                              From Here to Eternity     1953
# 9            9                                             Gandhi     1982
# 10          10                                 Gone with the Wind     1939
# ...

# %% [markdown]
# 3. Access the 2nd row and the 3rd column.AND Access the columns named Release and Nominations.

# %%
# Access the 2nd row and 3rd column
sec_row_thi_clmn = df.iloc[1, 2]

rls_noms = df[['Release', 'Nominations']]

# Displaying the results
sec_row_thi_clmn, rls_noms
# Out:
# (11,
#      Release  Nominations
#  0      1959           12
#  1      2003           11
#  2      1997           14
#  3      1961           11
#  4      1996           12
#  5      1958            9
#  6      1987            9
#  7      1984           11
#  8      1972           10
#  9      1953           13
#  10     1982           11
#  11     1939           13
#  12     1964           12
#  13     1954           12)

# %% [markdown]
# 4. Access the value for the row with index 10 and the column name 'Director' AND Access the value for the row with the index 2 and the column name 'Release'

# %%
rowten = df.at[10, 'Director']
rowtwo = df.at[2, 'Release']

rowten, rowtwo
# Out:
# ('Richard Attenborough', 1997)

# %% [markdown]
# 5. Add a new row to the DataFrame

# %%
# Creating a new row with the specified values

# Index 5
df.loc[4.5] = ['The Silence of the Lambs', 1991, 5, 7, 'Jonathan Demme', 118, 'English']
df = df.sort_index().reset_index(drop=True)
print(df)
# Out:
#                                             Movie  Release  Oscar number  \
# 0                        The Silence of the Lambs     1991             5
# 1   The Lord of the Rings: The Return of the King     2003            11
# 2                                         Titanic     1997            11
# 3                                 West Side Story     1961            10
# 4                             The English Patient     1996             9
# 5                        The Silence of the Lambs     1991             5
# 6                        The Silence of the Lambs     1991             5
# 7                                The Last Emperor     1987             9
# 8                                         Amadeus     1984             8
# 9                                         Cabaret     1972             8
# 10                          From Here to Eternity     1953             8
# 11                                         Gandhi     1982             8
# ...

# %%
# Removing the row with index 5
df = df.drop(index=0)

# %%
df
# Out:
#                                             Movie  Release  Oscar number  \
# 1   The Lord of the Rings: The Return of the King     2003            11
# 2                                         Titanic     1997            11
# 3                                 West Side Story     1961            10
# 4                             The English Patient     1996             9
# 5                        The Silence of the Lambs     1991             5
# 6                        The Silence of the Lambs     1991             5
# 7                                The Last Emperor     1987             9
# 8                                         Amadeus     1984             8
# 9                                         Cabaret     1972             8
# 10                          From Here to Eternity     1953             8
# 11                                         Gandhi     1982             8
# 12                             Gone with the Wind     1939             8
# ...

# %% [markdown]
# 6.

# %%
df.loc[0] = ['The Lord of the Rings: The Fellowship of the Ring', 2001, 4, 13, 'Peter Jackson', 178, 'English']
df = df.sort_index().reset_index(drop=True)
df
# Out:
#                                                 Movie  Release  Oscar number  \
# 0   The Lord of the Rings: The Fellowship of the Ring     2001             4
# 1       The Lord of the Rings: The Return of the King     2003            11
# 2                                             Titanic     1997            11
# 3                                     West Side Story     1961            10
# 4                                 The English Patient     1996             9
# 5                            The Silence of the Lambs     1991             5
# 6                            The Silence of the Lambs     1991             5
# 7                                    The Last Emperor     1987             9
# 8                                             Amadeus     1984             8
# 9                                             Cabaret     1972             8
# 10                              From Here to Eternity     1953             8
# ...

# %%
# Removing the row with index 15
df = df.drop(index=15)

# %%
df
# Out:
#                                                 Movie  Release  Oscar number  \
# 0   The Lord of the Rings: The Fellowship of the Ring     2001             4
# 1       The Lord of the Rings: The Return of the King     2003            11
# 2                                             Titanic     1997            11
# 3                                     West Side Story     1961            10
# 4                                 The English Patient     1996             9
# 5                            The Silence of the Lambs     1991             5
# 6                            The Silence of the Lambs     1991             5
# 7                                    The Last Emperor     1987             9
# 8                                             Amadeus     1984             8
# 9                                             Cabaret     1972             8
# 10                              From Here to Eternity     1953             8
# ...

# %%
# Removing the row with index 15, placed it in the wrong place
df = df.drop(index=0)
df
# Out:
#                                             Movie  Release  Oscar number  \
# 1   The Lord of the Rings: The Return of the King     2003            11
# 2                                         Titanic     1997            11
# 3                                 West Side Story     1961            10
# 4                             The English Patient     1996             9
# 5                        The Silence of the Lambs     1991             5
# 6                        The Silence of the Lambs     1991             5
# 7                                The Last Emperor     1987             9
# 8                                         Amadeus     1984             8
# 9                                         Cabaret     1972             8
# 10                          From Here to Eternity     1953             8
# 11                                         Gandhi     1982             8
# 12                             Gone with the Wind     1939             8
# ...

# %%
df.loc[15] = ['The Lord of the Rings: The Fellowship of the Ring', 2001, 4, 13, 'Peter Jackson', 178, 'English']
df = df.sort_index().reset_index(drop=True)
df
# Out:
#                                                 Movie  Release  Oscar number  \
# 0       The Lord of the Rings: The Return of the King     2003            11
# 1                                             Titanic     1997            11
# 2                                     West Side Story     1961            10
# 3                                 The English Patient     1996             9
# 4                            The Silence of the Lambs     1991             5
# 5                            The Silence of the Lambs     1991             5
# 6                                    The Last Emperor     1987             9
# 7                                             Amadeus     1984             8
# 8                                             Cabaret     1972             8
# 9                               From Here to Eternity     1953             8
# 10                                             Gandhi     1982             8
# ...

# %%
# Removing the row with index 15, I have duplicates
df = df.drop(index=4)
df
# Out:
#                                                 Movie  Release  Oscar number  \
# 0       The Lord of the Rings: The Return of the King     2003            11
# 1                                             Titanic     1997            11
# 2                                     West Side Story     1961            10
# 3                                 The English Patient     1996             9
# 5                            The Silence of the Lambs     1991             5
# 6                                    The Last Emperor     1987             9
# 7                                             Amadeus     1984             8
# 8                                             Cabaret     1972             8
# 9                               From Here to Eternity     1953             8
# 10                                             Gandhi     1982             8
# 11                                 Gone with the Wind     1939             8
# ...

# %% [markdown]
# 7. Export the current version of your DataFrame as an Excel file with a new name

# %%
# Name of the file
df.to_excel('my_movies_data.xlsx', index=False)

print('Exported successfully.')
# Out:
# Exported successfully.

# %%
df
# Out:
#                                                 Movie  Release  Oscar number  \
# 0       The Lord of the Rings: The Return of the King     2003            11
# 1                                             Titanic     1997            11
# 2                                     West Side Story     1961            10
# 3                                 The English Patient     1996             9
# 5                            The Silence of the Lambs     1991             5
# 6                                    The Last Emperor     1987             9
# 7                                             Amadeus     1984             8
# 8                                             Cabaret     1972             8
# 9                               From Here to Eternity     1953             8
# 10                                             Gandhi     1982             8
# 11                                 Gone with the Wind     1939             8
# ...

# %%
#Checking if it exported and changed name
import pandas as pd
xlsx_path = 'my_movies_data.xlsx'
df = pd.read_excel(xlsx_path)
df
# Out:
#     Unnamed: 0                                              Movie  Release  \
# 0            0      The Lord of the Rings: The Return of the King     2003
# 1            1                                            Titanic     1997
# 2            2                                    West Side Story     1961
# 3            3                                The English Patient     1996
# 4            4                           The Silence of the Lambs     1991
# 5            5                                   The Last Emperor     1987
# 6            6                                            Amadeus     1984
# 7            7                                            Cabaret     1972
# 8            8                              From Here to Eternity     1953
# 9            9                                             Gandhi     1982
# 10          10                                 Gone with the Wind     1939
# ...
